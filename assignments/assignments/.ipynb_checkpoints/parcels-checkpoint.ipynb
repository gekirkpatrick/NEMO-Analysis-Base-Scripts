# %% [markdown]
# Code for calculating the barotropic and overturning streamfunctions

# %%
import os
os.environ['MPLCONFIGDIR'] = "/mnt/storage4/grace/grace/plt_temp/"

import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import netCDF4 as nc
